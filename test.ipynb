# %%
import IPython.display as ipd
ipd.Video('video.mp4', width=480, embed=True)
# Out:
# <video controls  width="480" >
#  <source src="....mp4" type="None">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# # test
#
# this is an idea

# %% [markdown]
# ![image.png](attachment:image.png)
